# %%
import math

# %% [markdown]
# cards = [13, 11, 10, 7, 4, 3, 1, 0]
# query = 7
# output = 3

# %%
math.sqrt(49)
cards = [13, 11, 10, 7, 4, 3, 1, 0]
query = 7
output = 3
result = locate_card(cards, query)
print(result)result == output
# Out:
# 7.0

# %% [markdown]
# result = locate_card(cards, query)
# print(result)

# %% [markdown]
# result == output
