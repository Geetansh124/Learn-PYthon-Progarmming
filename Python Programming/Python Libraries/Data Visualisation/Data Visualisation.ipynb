# %% [markdown]
# **Data Visualisation**

# %%
#import pandas as pd
#from pandas import DataFrame
#from pandas import *


import math

print(math.sqrt(16))

import pandas as pd

data = pd.DataFrame({"Name":['This is a dataframe']})
print(data)
# Out:
# 4.0
#                   Name
# 0  This is a dataframe
