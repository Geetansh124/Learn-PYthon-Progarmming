# %%
print("Hello World, Welcome to this world")
# Out:
# Hello World, Welcome to this world

# %%
print("This World is About the Data Science")

# %%
def recursive_min(L):
    if len(L) == 1:
        return L[0]
    return L[0] if L[0] < recursive_min(L[1:]) else recursive_min(L[1:])
